# %%
import pandas as pd
df = pd.read_csv("/home/manassecodev/dev/data-science-beginner/dataset/data.csv")
# Out:
#   Cell In[1], line 1
#     pandas as pd
#            ^
# SyntaxError: invalid syntax
